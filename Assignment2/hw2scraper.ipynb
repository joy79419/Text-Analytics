# %%
# Import webdriver from selenium
from selenium import webdriver
chrome_path = r'/Users/shanqin/Desktop/TextaAnalysis/chromedriver'
# prepend it with r because of the backslash characters

# %%
import os
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import numpy as np
import pandas as pd

# %%
def get_date(soup):
    date = []
    for element in soup.find_all(class_='MItem DateCreated'):
        date.append(element.find('time').text.strip())
    return date

# %%
def get_userid(soup):
    userid = []
    for element in soup.find_all(class_='Comment'):
        userid.append(element.find_all('span')[0].text.strip())
    return userid

# %% [markdown]
# def get_message(soup):
#     msg = []
#     for element in soup.find_all(class_='Comment'):
#         msg.append(element.find_all('div')[6].text.strip())
#     return msg

# %%
def remove_quote(soup):
    cleantext = []
    for k in soup.find_all('br'):
        k.extract()
        text = soup.find_all('div',{'class':'Message'})
        for t in text:
            if t.find('blockquote'):
                try:
                    cleantext.append(t.contents[2].strip())
                except:
                    cleantext.append(u"")
            else:
                cleantext.append(t.contents[0].strip())
    return cleantext

# %%
def get_data (url, driver, pages):
    date = []
    userid = []
    msg = []
    for i in range (pages):
        driver.get(url)
        soup = BeautifulSoup(driver.page_source,'html.parser')
        date += get_date(soup)
        userid += get_userid(soup)
        msg += remove_quote(soup)
        next_button = soup.find("a", class_="Previous Pager-nav")
        url = next_button['href']
    return pd.DataFrame(list(zip(date, userid, msg)))

# %%
url = "https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p702"
driver = webdriver.Chrome(chrome_path)
get_data(url, driver, 5)
# Out:
#                 0             1  \
# 0     September 7       dino001
# 1     September 7       circlew
# 2     September 8       qbrozen
# 3     September 9  FlightNurse2
# 4     September 9    roadburner
# 5     September 9  FlightNurse2
# 6     September 9    roadburner
# 7     September 9       dino001
# 8    September 24    benjaminhf
# 9    September 24      stickguy
# 10   September 24         kyfdx
# 11   September 26    benjaminhf
# 12   September 26      stickguy
# 13   September 26    benjaminhf
# 14   September 26    benjaminhf
# 15   September 26      stickguy
# 16   September 26    benjaminhf
# 17   September 26    benjaminhf
# 18   September 26      stickguy
# 19   September 26    benjaminhf
# 20   September 26      stickguy
# 21   September 26    roadburner
# 22        12:09AM       qbrozen
# 23        12:17AM     carnaught
# 24        12:46AM      stickguy
# 25       August 7     benjaminh
# 26       August 8       andres3
# 27       August 8     benjaminh
# 28       August 8           sda
# 29       August 8        henryn
# ..            ...           ...
# 115       July 17     benjaminh
# 116       July 17      stickguy
# 117       July 17     benjaminh
# 118       July 17         kyfdx
# 119       July 17       andres3
# 120       July 19   flightnurse
# 121       July 19      stickguy
# 122       July 19       qbrozen
# 123       July 19     benjaminh
# 124       July 19       qbrozen
# 125       July 19      stickguy
# 126       July 19   flightnurse
# 127       July 19   flightnurse
# 128       July 19       qbrozen
# 129       July 19   flightnurse
# 130       July 19   flightnurse
# 131       July 19      stickguy
# 132       July 19   flightnurse
# 133       July 19        henryn
# 134       July 19       qbrozen
# 135       July 19     benjaminh
# 136       July 19      Michaell
# 137       July 19    roadburner
# 138       July 20     benjaminh
# 139       July 20    cdnpinhead
# 140       July 20       andres3
# 141       July 20       andres3
# 142       July 20   flightnurse
# 143       July 20     benjaminh
# 144       July 21       andres3
#
#                                                      2
# 0    If they keep it around in next four-five years...
# 1    The lease rate is the factor that stops me col...
# 2    Yes, the completely noncomparable M2 would bea...
# 3                 Why not a Genesis G70 with a manual?
# 4    Again, the local dealer are hopeless at best(W...
# 5    Are you talking about Genesis Dealers or Hyund...
# 6    Thanks, but I am more than aware of the distin...
# 7    Yeah, I went once to an AutoNation Lexus store...
# 8    I am the poster formerly known as benjaminh an...
# 9    Still on the list.  Just have not been looking...
# 10                                I sent you a message
# 11   A new and mostly positive review by Kelly Blue...
# 12   If I do manage to upgrade to a TLX it would ha...
# 13   Thanks. I'll give it a try at some point to me...
# 14   I'm not sure if I'd have the patience and disc...
# 15   They usually go up as the year goes along. Chr...
# 16   Yeah, I was and am a bit concerned with gettin...
# 17   The KBB reviewer makes some good points about ...
# 18   I like the 2 screen set up, for just the reaso...
# 19   My local Cadillac dealer has their last ATS av...
# 20   I would take it.  without even looking at the ...
# 21   That dealer has the same GM as my BMW dealer- ...
# 22   The fine lrint for all says "plus dealer add-o...
# 23   The CTS looks like a smokin’n deal if your nam...
# 24   so the car is $199/month, and the mop and glow...
# 25   If they keep it around in next four-five years...
# 26   The lease rate is the factor that stops me col...
# 27   Yes, the completely noncomparable M2 would bea...
# 28                Why not a Genesis G70 with a manual?
# 29   Again, the local dealer are hopeless at best(W...
# ..                                                 ...
# 115  They usually go up as the year goes along. Chr...
# 116  Yeah, I was and am a bit concerned with gettin...
# 117  The KBB reviewer makes some good points about ...
# 118  I like the 2 screen set up, for just the reaso...
# 119  My local Cadillac dealer has their last ATS av...
# 120  I would take it.  without even looking at the ...
# 121  That dealer has the same GM as my BMW dealer- ...
# 122  The fine lrint for all says "plus dealer add-o...
# 123  The CTS looks like a smokin’n deal if your nam...
# 124  so the car is $199/month, and the mop and glow...
# 125  If they keep it around in next four-five years...
# 126  The lease rate is the factor that stops me col...
# 127  Yes, the completely noncomparable M2 would bea...
# 128               Why not a Genesis G70 with a manual?
# 129  Again, the local dealer are hopeless at best(W...
# 130  Are you talking about Genesis Dealers or Hyund...
# 131  Thanks, but I am more than aware of the distin...
# 132  Yeah, I went once to an AutoNation Lexus store...
# 133  I am the poster formerly known as benjaminh an...
# 134  Still on the list.  Just have not been looking...
# 135                               I sent you a message
# 136  A new and mostly positive review by Kelly Blue...
# 137  If I do manage to upgrade to a TLX it would ha...
# 138  Thanks. I'll give it a try at some point to me...
# 139  I'm not sure if I'd have the patience and disc...
# 140  They usually go up as the year goes along. Chr...
# 141  Yeah, I was and am a bit concerned with gettin...
# 142  The KBB reviewer makes some good points about ...
# 143  I like the 2 screen set up, for just the reaso...
# 144  My local Cadillac dealer has their last ATS av...
#
# [145 rows x 3 columns]
