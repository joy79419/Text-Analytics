# %%
from pandas import Series, DataFrame
import pandas as pd
from patsy import dmatrices

# %pylab inline
import re
import string
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#comments are coming in as utf-8 so I am using this code to change it back to ascii
def unicodetoascii(text):

    TEXT = (text.
    		replace('\xe2\x80\x99', "'").
            replace('\xc3\xa9', 'e').
            replace('\xe2\x80\x90', '-').
            replace('\xe2\x80\x91', '-').
            replace('\xe2\x80\x92', '-').
            replace('\xe2\x80\x93', '-').
            replace('\xe2\x80\x94', '-').
            replace('\xe2\x80\x94', '-').
            replace('\xe2\x80\x98', "'").
            replace('\xe2\x80\x9b', "'").
            replace('\xe2\x80\x9c', '"').
            replace('\xe2\x80\x9c', '"').
            replace('\xe2\x80\x9d', '"').
            replace('\xe2\x80\x9e', '"').
            replace('\xe2\x80\x9f', '"').
            replace('\xe2\x80\xa6', '...').#
            replace('\xe2\x80\xb2', "'").
            replace('\xe2\x80\xb3', "'").
            replace('\xe2\x80\xb4', "'").
            replace('\xe2\x80\xb5', "'").
            replace('\xe2\x80\xb6', "'").
            replace('\xe2\x80\xb7', "'").
            replace('\xe2\x81\xba', "+").
            replace('\xe2\x81\xbb', "-").
            replace('\xe2\x81\xbc', "=").
            replace('\xe2\x81\xbd', "(").
            replace('\xe2\x81\xbe', ")")

                 )
    return TEXT

# %%
data = pd.read_csv('final.csv', sep=',',names=['id', 'date','user','text'], header = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-cf3aa823d6ef> in <module>()
# ----> 1 data = pd.read_csv('final.csv', sep=',',names=['id', 'date','user','text'], header = False)
#
# ~/anaconda2/envs/Python3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~/anaconda2/envs/Python3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# ~/anaconda2/envs/Python3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     780         # might mutate self.engine
#     781         self.engine = self._check_file_or_buffer(f, engine)
# --> 782         self.options, self.engine = self._clean_options(options, engine)
#     783
#     784         if 'has_index_names' in kwds:
#
# ~/anaconda2/envs/Python3/lib/python3.6/site-packages/pandas/io/parsers.py in _clean_options(self, options, engine)
#     937         skiprows = options['skiprows']
#     938
# --> 939         _validate_header_arg(options['header'])
#     940
#     941         depr_warning = ''
#
# ~/anaconda2/envs/Python3/lib/python3.6/site-packages/pandas/io/common.py in _validate_header_arg(header)
#     113 def _validate_header_arg(header):
#     114     if isinstance(header, bool):
# --> 115         raise TypeError("Passing a bool to header is invalid. "
#     116                         "Use header=None for no header or "
#     117                         "header=int or list-like of ints to specify "
#
# TypeError: Passing a bool to header is invalid. Use header=None for no header or header=int or list-like of ints to specify the row(s) making up the column names

# %%
data
# Out:
#           id          date            user  \
# 0        NaN             0               1
# 1        0.0   September 7         dino001
# 2        1.0   September 7         circlew
# 3        2.0   September 8         qbrozen
# 4        3.0   September 9    FlightNurse2
# 5        4.0   September 9      roadburner
# 6        5.0   September 9    FlightNurse2
# 7        6.0   September 9      roadburner
# 8        7.0   September 9         dino001
# 9        8.0  September 24      benjaminhf
# 10       9.0  September 24        stickguy
# 11      10.0  September 24           kyfdx
# 12      11.0  September 26      benjaminhf
# 13      12.0  September 26        stickguy
# 14      13.0  September 26      benjaminhf
# 15      14.0  September 26      benjaminhf
# 16      15.0  September 26        stickguy
# 17      16.0  September 26      benjaminhf
# 18      17.0  September 26      benjaminhf
# 19      18.0  September 26        stickguy
# 20      19.0  September 26      benjaminhf
# 21      20.0  September 26        stickguy
# 22      21.0  September 26      roadburner
# 23      22.0       12:09AM         qbrozen
# 24      23.0       12:17AM       carnaught
# 25      24.0       12:46AM        stickguy
# 26      25.0        2:19AM      roadburner
# 27      26.0        2:22AM         qbrozen
# 28      27.0      August 7       benjaminh
# 29      28.0      August 8         andres3
# ...      ...           ...             ...
# 5068  5067.0   August 2013         andres3
# 5069  5068.0   August 2013           kyfdx
# 5070  5069.0   August 2013         dino001
# 5071  5070.0   August 2013      graphicguy
# 5072  5071.0   August 2013     flightnurse
# 5073  5072.0   August 2013     flightnurse
# 5074  5073.0   August 2013      graphicguy
# 5075  5074.0   August 2013        rayainsw
# 5076  5075.0   August 2013       fedlawman
# 5077  5076.0   August 2013        rayainsw
# 5078  5077.0   August 2013           kyfdx
# 5079  5078.0   August 2013       fedlawman
# 5080  5079.0   August 2013           kyfdx
# 5081  5080.0   August 2013       fedlawman
# 5082  5081.0   August 2013     igozoomzoom
# 5083  5082.0   August 2013           gpb59
# 5084  5083.0   August 2013         dino001
# 5085  5084.0   August 2013     flightnurse
# 5086  5085.0   August 2013         andres3
# 5087  5086.0   August 2013       sweendogy
# 5088  5087.0   August 2013         andres3
# 5089  5088.0   August 2013         dino001
# 5090  5089.0   August 2013        andys120
# 5091  5090.0   August 2013         andres3
# 5092  5091.0   August 2013       sweendogy
# 5093  5092.0   August 2013  markcincinnati
# 5094  5093.0   August 2013     flightnurse
# 5095  5094.0   August 2013       sweendogy
# 5096  5095.0   August 2013         andres3
# 5097  5096.0   August 2013       sweendogy
#
#                                                    text
# 0                                                     2
# 1     If they keep it around in next four-five years...
# 2     The lease rate is the factor that stops me col...
# 3     Yes, the completely noncomparable M2 would bea...
# 4                  Why not a Genesis G70 with a manual?
# 5     Again, the local dealer are hopeless at best(W...
# 6     Are you talking about Genesis Dealers or Hyund...
# 7     Thanks, but I am more than aware of the distin...
# 8     Yeah, I went once to an AutoNation Lexus store...
# 9     I am the poster formerly known as benjaminh an...
# 10    Still on the list.  Just have not been looking...
# 11                                 I sent you a message
# 12    A new and mostly positive review by Kelly Blue...
# 13    If I do manage to upgrade to a TLX it would ha...
# 14    Thanks. I'll give it a try at some point to me...
# 15    I'm not sure if I'd have the patience and disc...
# 16    They usually go up as the year goes along. Chr...
# 17    Yeah, I was and am a bit concerned with gettin...
# 18    The KBB reviewer makes some good points about ...
# 19    I like the 2 screen set up, for just the reaso...
# 20    My local Cadillac dealer has their last ATS av...
# 21    I would take it.  without even looking at the ...
# 22    That dealer has the same GM as my BMW dealer- ...
# 23    The fine lrint for all says "plus dealer add-o...
# 24    The CTS looks like a smokin’n deal if your nam...
# 25    so the car is $199/month, and the mop and glow...
# 26      If I was 25 years older I might an XT5 as well.
# 27    Its a hard knock life when 0-60 in 6.5 secs in...
# 28    One of the features I like on my TLX's stereo ...
# 29    What's the storage capacity in GB?  If uncompr...
# ...                                                 ...
# 5068  I did find it annoying the XXX number iS model...
# 5069  graphicguy had the dealer apply the performanc...
# 5070  I think the "is" is available on coupe only be...
# 5071  [i]graphicguy had the dealer apply the perform...
# 5072  "graphicguy had the dealer apply the performan...
# 5073  It's been reported by  a couple of vendors tha...
# 5074  FN...nope.  Mine was the 335i with the perform...
# 5075  'I did find it annoying the XXX number iS mode...
# 5076  You should have put a Dinan sticker on your re...
# 5077                         It was actually the 370 TQ
# 5078  When I bought my 330Ci, the model designation ...
# 5079             Yes, that's an often overlooked tweak!
# 5080  Oh yeah... subbed in black grilles...    they ...
# 5081  Oh boy! We'll be up to 400 hp and 40 MPG the r...
# 5082  I was looking thru the inventory at a local BM...
# 5083  I'm considering a preowned 2012 or 2013, when ...
# 5084  I didn't observe this trend here yet (majority...
# 5085  "Oh boy! We'll be up to 400 hp and 40 MPG the ...
# 5086  I've technically just "ordered" my custom equi...
# 5087  Observation and opinion -  don't see many 335 ...
# 5088  Our companies 45K mile Odyssey has a warped ro...
# 5089  It is Imperial Blue (dark) or Estoril Blue (Li...
# 5090                                                NaN
# 5091  I didn't opt for a rear backup camera on my ne...
# 5092  Get a go pro camera and mt to dash- plenty of ...
# 5093  I'm with you -- backup cameras are quite helpf...
# 5094  Mark, I in the last 3 months, I have had 4 inf...
# 5095  You know what else is huge.. The money I saved...
# 5096                    ahhh, I misspoke and mis-wrote.
# 5097  Yeah those lines are useful for spots- I also ...
#
# [5098 rows x 4 columns]

# %%
data.drop(data.index[:1], inplace=True)

# %%
data[:5]
# Out:
#     id         date          user  \
# 1  0.0  September 7       dino001
# 2  1.0  September 7       circlew
# 3  2.0  September 8       qbrozen
# 4  3.0  September 9  FlightNurse2
# 5  4.0  September 9    roadburner
#
#                                                 text
# 1  If they keep it around in next four-five years...
# 2  The lease rate is the factor that stops me col...
# 3  Yes, the completely noncomparable M2 would bea...
# 4               Why not a Genesis G70 with a manual?
# 5  Again, the local dealer are hopeless at best(W...

# %%
#text field is the comments field
#unicodetoascii changes the form from unicoding to regular english
#making all the comments lower case
#dt = data.iloc[:50]
text = data['text']
text = text.map(lambda a: unicodetoascii(str(a)))
text = text.map(lambda a: a.lower())

#text= text.map(lambda a: str(a).decode('ascii', errors='ignore'))
#text_18 = text.loc[18]

#text_18 = text_18.decode("ascii", errors="ignore")
#text_18

# %%
models = pd.read_csv('models.csv', sep=',',names=['brand','model'],encoding='windows-1252')
models_revised = pd.read_csv('models_revised.csv', sep=',',names=['brand','model'],encoding='windows-1252')

# %%
#this text is also in unicode so just replacing one of the symbols with a space 
#(we can also call the unicodetoascii function here for more robust cleaning)
#making the model names lowercase
models.model = models['model'].map(lambda x: x.replace('\xa0', ''))
models.model = models['model'].map(lambda x: x.lower())
models_revised.model = models_revised['model'].map(lambda x: x.replace('\xa0', ''))
models_revised.model = models_revised['model'].map(lambda x: x.lower())

# %%
#create dictionary {model: brand}
#this will be used when locating when the model is written, and replacing it to the brand name
brand_dict = {}
for i in range(len(models_revised)):
    brand_dict[models_revised['model'][i]] = models_revised['brand'][i]

# %%
#replace all models with brand names


#for key in brand_dict.iterkeys():
 #   dt['text'] = dt['text'].map(lambda x: x.replace(key, brand_dict[key]))
    
#dt['text']
#for key in brand_dict.iterkeys():
#    text_18 = text_18.replace(key, brand_dict[key])
#text_18

def replace(match):
    return brand_dict[match.group(0)]

text = text.map(lambda x: re.sub(''.join(r'\b%s' % re.escape(s) for s in brand_dict), 
        replace, x) )

#text_18 =  re.sub('|'.join(r'\b%s' % re.escape(s) for s in brand_dict), 
#        replace, text_18)

# %%
#finding all of the unique/different brand names
brand = list(set(models_revised.brand))

# %%
#findall: takes each comment separately, finds every time any brand is mentioned, and adds it to the master list
#set(ls): this makes sure that even if the brand is mentioned more than once, it is only recorded once
master_list = []

def findall(w):
    ls = []
    ls = [e for e in brand for i in w.split() if e in i] #this line finds where the brand is mentioned in the comment (could be
    # of any format: ex. "honda."| "honda's" | "honda-and" | etc., and records it as just "honda")
    ls = list(set(ls))
    master_list.append(ls) #this stores all the mentions of every comment we have
text.map(findall)

count_list = sum(master_list)

# %%
count_series = pd.Series(count_list).value_counts()
count_series[:10]
# Out:
# bmw           532
# audi          457
# toyota        231
# acura         217
# honda         205
# volkswagen    131
# infiniti      106
# hyundai       103
# cadillac       98
# ford           97
# dtype: int64

# %%
from collections import Counter
#counts the number of mentions each brand has and displays the top 10

counts = Counter(count_list)
counts.most_common(10)
# Out:
# [('bmw', 532),
#  ('audi', 457),
#  ('toyota', 231),
#  ('acura', 217),
#  ('honda', 205),
#  ('volkswagen', 131),
#  ('infiniti', 106),
#  ('hyundai', 103),
#  ('cadillac', 98),
#  ('ford', 97)]

# %%
#list = []
#list = [i for e in brand for i in text_18.split() if e in i]
#for b in brand:
#    for c in list:
#        if re.search(b , c):
#            list = [word.replace(c,b) for word in list]
#set(list)

# %%
#def ratio(a, b):
#    a = float(a)
#    b = float(b)
#    if b == 0:
#        return a
#    return ratio(b, a % b)

#def get_ratio(a, b):
#    r = ratio(a, b)
#    return "%s" % float((a/r) / (b/r))

# %%
master_list = list(filter(None,master_list))
master_list
# Out:
# [['bmw', 'kia'],
#  ['chevrolet'],
#  ['hyundai'],
#  ['hyundai'],
#  ['acura', 'pontiac', 'kia', 'hyundai', 'infiniti'],
#  ['hyundai'],
#  ['bmw', 'ford', 'audi', 'volvo', 'toyota'],
#  ['acura'],
#  ['acura', 'toyota'],
#  ['honda'],
#  ['honda'],
#  ['toyota'],
#  ['cadillac'],
#  ['bmw'],
#  ['honda'],
#  ['acura'],
#  ['honda'],
#  ['bmw'],
#  ['audi'],
#  ['honda'],
#  ['hyundai', 'acura'],
#  ['honda'],
#  ['volkswagen', 'honda'],
#  ['hyundai', 'audi', 'honda'],
#  ['acura', 'audi', 'honda'],
#  ['volkswagen'],
#  ['volkswagen', 'honda'],
#  ['volkswagen'],
#  ['toyota', 'honda', 'volkswagen'],
#  ['honda'],
#  ['cadillac'],
#  ['acura', 'audi', 'bmw'],
#  ['audi', 'honda'],
#  ['honda'],
#  ['kia.', 'kia'],
#  ['toyota'],
#  ['volkswagen'],
#  ['volkswagen'],
#  ['toyota'],
#  ['volkswagen'],
#  ['audi', 'ford'],
#  ['mazda', 'audi', 'cadillac', 'mercedes-benz', 'mercedes'],
#  ['honda'],
#  ['honda'],
#  ['chevrolet'],
#  ['bmw'],
#  ['acura'],
#  ['honda'],
#  ['bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['pontiac'],
#  ['honda'],
#  ['acura', 'honda'],
#  ['honda'],
#  ['kia.', 'kia'],
#  ['honda'],
#  ['acura', 'honda'],
#  ['toyota', 'honda'],
#  ['acura'],
#  ['bmw'],
#  ['acura', 'honda'],
#  ['honda'],
#  ['bmw'],
#  ['bmw'],
#  ['toyota'],
#  ['toyota'],
#  ['cadillac'],
#  ['audi', 'bmw', 'honda'],
#  ['kia'],
#  ['honda'],
#  ['acura'],
#  ['toyota', 'honda'],
#  ['honda'],
#  ['acura', 'honda'],
#  ['honda'],
#  ['acura'],
#  ['acura', 'toyota', 'honda'],
#  ['ford'],
#  ['mercedes', 'audi', 'bmw'],
#  ['mazda', 'bmw'],
#  ['audi'],
#  ['audi'],
#  ['audi'],
#  ['audi'],
#  ['audi', 'honda'],
#  ['kia'],
#  ['audi', 'honda'],
#  ['honda'],
#  ['honda'],
#  ['honda'],
#  ['toyota', 'honda'],
#  ['toyota'],
#  ['acura', 'honda'],
#  ['audi', 'volvo'],
#  ['acura', 'audi'],
#  ['volvo'],
#  ['acura'],
#  ['acura', 'honda'],
#  ['acura'],
#  ['volvo'],
#  ['acura'],
#  ['audi'],
#  ['hyundai'],
#  ['toyota', 'honda'],
#  ['acura', 'toyota', 'honda'],
#  ['audi'],
#  ['kia'],
#  ['bmw', 'ford'],
#  ['kia'],
#  ['toyota'],
#  ['kia'],
#  ['kia', 'ford'],
#  ['audi', 'bmw', 'kia'],
#  ['hyundai', 'kia', 'kia,'],
#  ['hyundai', 'toyota', 'kia.', 'kia'],
#  ['ford'],
#  ['kia'],
#  ['bmw', 'kia'],
#  ['kia'],
#  ['cadillac'],
#  ['audi'],
#  ['bmw'],
#  ['bmw', 'kia'],
#  ['bmw', 'cadillac'],
#  ['toyota'],
#  ['bmw'],
#  ['toyota', 'bmw'],
#  ['audi', 'bmw', 'kia'],
#  ['kia', 'ford'],
#  ['kia'],
#  ['bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['hyundai', 'bmw'],
#  ['audi', 'bmw', 'kia'],
#  ['kia'],
#  ['audi', 'bmw'],
#  ['audi', 'honda'],
#  ['audi', 'bmw'],
#  ['audi'],
#  ['kia'],
#  ['toyota'],
#  ['hyundai', 'nissan', 'kia', 'kia,'],
#  ['audi', 'bmw', 'kia'],
#  ['hyundai', 'bmw'],
#  ['hyundai'],
#  ['bmw'],
#  ['buick', 'volvo'],
#  ['kia'],
#  ['dodge', 'ford', 'nissan', 'chevrolet', 'subaru'],
#  ['bmw'],
#  ['kia'],
#  ['bmw'],
#  ['bmw'],
#  ['buick', 'mercury', 'bmw'],
#  ['bmw', 'kia'],
#  ['audi'],
#  ['kia.', 'bmw', 'kia'],
#  ['bmw'],
#  ['toyota'],
#  ['audi'],
#  ['audi'],
#  ['audi'],
#  ['acura'],
#  ['toyota', 'bmw', 'cadillac'],
#  ['audi'],
#  ['audi'],
#  ['audi'],
#  ['infiniti'],
#  ['audi'],
#  ['bmw'],
#  ['bmw', 'kia', 'nissan', 'hyundai', 'kia.', 'toyota', 'honda'],
#  ['volkswagen', 'audi'],
#  ['acura', 'honda'],
#  ['bmw', 'kia', 'nissan', 'hyundai', 'kia.', 'toyota', 'honda'],
#  ['nissan', 'bmw'],
#  ['bmw'],
#  ['kia'],
#  ['mazda', 'bmw'],
#  ['bmw', 'kia'],
#  ['hyundai', 'mazda'],
#  ['mazda'],
#  ['audi'],
#  ['toyota'],
#  ['hyundai', 'audi'],
#  ['hyundai', 'audi'],
#  ['hyundai', 'pontiac', 'kia'],
#  ['mazda', 'dodge'],
#  ['nissan', 'audi'],
#  ['honda', 'cadillac'],
#  ['volkswagen', 'audi', 'bmw', 'kia'],
#  ['audi'],
#  ['acura', 'honda'],
#  ['audi'],
#  ['audi'],
#  ['bmw'],
#  ['buick', 'bmw'],
#  ['acura', 'audi', 'bmw'],
#  ['toyota', 'audi', 'ford'],
#  ['bmw'],
#  ['mazda', 'bmw'],
#  ['mazda'],
#  ['audi'],
#  ['toyota'],
#  ['acura', 'honda'],
#  ['buick', 'acura'],
#  ['honda'],
#  ['acura', 'honda'],
#  ['buick', 'acura', 'bmw', 'infiniti'],
#  ['mazda', 'bmw', 'infiniti'],
#  ['acura', 'pontiac', 'bmw', 'audi', 'infiniti'],
#  ['acura'],
#  ['acura', 'honda'],
#  ['acura', 'infiniti'],
#  ['acura', 'toyota', 'honda'],
#  ['acura', 'infiniti', 'honda', 'nissan'],
#  ['acura', 'honda'],
#  ['acura', 'honda'],
#  ['volvo'],
#  ['volkswagen', 'audi', 'volvo'],
#  ['pontiac', 'bmw'],
#  ['kia.', 'bmw', 'kia'],
#  ['bmw'],
#  ['bmw'],
#  ['pontiac'],
#  ['audi'],
#  ['toyota', 'bmw'],
#  ['mercedes-benz', 'mercedes'],
#  ['bmw', 'audi', 'cadillac', 'volvo', 'mercedes'],
#  ['audi'],
#  ['audi'],
#  ['acura'],
#  ['mercedes-benz', 'mercedes'],
#  ['audi'],
#  ['audi'],
#  ['toyota'],
#  ['toyota'],
#  ['bmw'],
#  ['bmw'],
#  ['toyota'],
#  ['bmw'],
#  ['chevrolet'],
#  ['hyundai'],
#  ['bmw', 'volvo'],
#  ['volvo'],
#  ['mercedes-benz', 'bmw', 'mercedes'],
#  ['hyundai', 'kia.', 'kia'],
#  ['hyundai'],
#  ['hyundai'],
#  ['bmw'],
#  ['hyundai', 'pontiac'],
#  ['pontiac'],
#  ['bmw'],
#  ['pontiac'],
#  ['pontiac'],
#  ['pontiac'],
#  ['bmw'],
#  ['dodge'],
#  ['pontiac', 'bmw'],
#  ['hyundai'],
#  ['bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['infiniti'],
#  ['bmw'],
#  ['audi', 'bmw'],
#  ['bmw', 'honda'],
#  ['cadillac'],
#  ['cadillac', 'chevrolet', 'mercedes-benz', 'buick', 'mercedes'],
#  ['bmw', 'ford'],
#  ['buick', 'cadillac'],
#  ['hyundai'],
#  ['hyundai', 'acura'],
#  ['hyundai', 'volvo'],
#  ['mazda'],
#  ['subaru', 'honda', 'toyota'],
#  ['bmw'],
#  ['acura', 'honda'],
#  ['bmw'],
#  ['bmw'],
#  ['acura'],
#  ['acura', 'honda'],
#  ['acura'],
#  ['bmw'],
#  ['bmw'],
#  ['audi'],
#  ['honda'],
#  ['toyota', 'audi'],
#  ['bmw'],
#  ['toyota', 'bmw'],
#  ['audi'],
#  ['audi'],
#  ['toyota', 'bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['audi', 'bmw'],
#  ['toyota', 'audi', 'infiniti'],
#  ['volvo'],
#  ['bmw', 'volvo'],
#  ['audi', 'bmw'],
#  ['chrysler', 'toyota', 'chevrolet'],
#  ['volkswagen', 'audi', 'bmw'],
#  ['audi'],
#  ['audi'],
#  ['audi'],
#  ['audi'],
#  ['audi'],
#  ['audi'],
#  ['audi'],
#  ['audi'],
#  ['acura'],
#  ['acura'],
#  ['acura'],
#  ['acura', 'volkswagen'],
#  ['acura'],
#  ['honda'],
#  ['acura', 'honda'],
#  ['audi', 'bmw'],
#  ['bmw'],
#  ['volkswagen', 'volvo'],
#  ['toyota'],
#  ['volvo'],
#  ['bmw'],
#  ['cadillac'],
#  ['bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['cadillac'],
#  ['bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['audi'],
#  ['hyundai', 'kia'],
#  ['bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['honda', 'cadillac'],
#  ['acura'],
#  ['volvo'],
#  ['volvo'],
#  ['cadillac'],
#  ['subaru', 'cadillac'],
#  ['cadillac'],
#  ['cadillac'],
#  ['toyota'],
#  ['cadillac'],
#  ['cadillac'],
#  ['audi'],
#  ['bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['audi'],
#  ['hyundai', 'audi'],
#  ['audi'],
#  ['nissan', 'volkswagen', 'audi'],
#  ['volkswagen', 'audi', 'honda'],
#  ['toyota'],
#  ['bmw', 'ford'],
#  ['ford'],
#  ['bmw'],
#  ['honda'],
#  ['ford'],
#  ['audi'],
#  ['audi'],
#  ['audi', 'bmw'],
#  ['audi', 'infiniti'],
#  ['bmw'],
#  ['audi'],
#  ['audi'],
#  ['subaru'],
#  ['subaru'],
#  ['subaru'],
#  ['subaru'],
#  ['acura'],
#  ['chrysler'],
#  ['volkswagen', 'audi'],
#  ['acura'],
#  ['acura'],
#  ['acura'],
#  ['audi'],
#  ['audi'],
#  ['volkswagen'],
#  ['hyundai', 'bmw'],
#  ['toyota'],
#  ['audi'],
#  ['bmw'],
#  ['bmw'],
#  ['hyundai', 'bmw'],
#  ['audi', 'bmw'],
#  ['bmw'],
#  ['audi', 'honda'],
#  ['subaru'],
#  ['bmw'],
#  ['honda'],
#  ['acura', 'honda'],
#  ['audi', 'bmw'],
#  ['volkswagen'],
#  ['bmw'],
#  ['bmw'],
#  ['volkswagen'],
#  ['volkswagen'],
#  ['honda'],
#  ['mazda', 'audi'],
#  ['audi'],
#  ['nissan', 'infiniti'],
#  ['bmw'],
#  ['acura', 'volkswagen', 'honda', 'mercury'],
#  ['hyundai', 'bmw'],
#  ['hyundai'],
#  ['hyundai', 'mazda', 'bmw'],
#  ['audi', 'bmw'],
#  ['audi'],
#  ['audi'],
#  ['bmw'],
#  ['toyota'],
#  ['bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['mazda', 'bmw'],
#  ['pontiac'],
#  ['chevrolet'],
#  ['toyota'],
#  ['hyundai'],
#  ['bmw'],
#  ['kia.', 'kia'],
#  ['mazda'],
#  ['bmw'],
#  ['mazda'],
#  ['bmw'],
#  ['hyundai'],
#  ['bmw'],
#  ['volkswagen', 'ford'],
#  ['bmw', 'honda'],
#  ['bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['ford'],
#  ['bmw'],
#  ['audi', 'bmw'],
#  ['bmw'],
#  ['mazda'],
#  ['hyundai', 'mercedes'],
#  ['lincoln', 'ford'],
#  ['lincoln'],
#  ['acura', 'audi', 'bmw', 'infiniti'],
#  ['acura'],
#  ['subaru'],
#  ['hyundai'],
#  ['nissan', 'toyota', 'honda', 'volkswagen'],
#  ['hyundai', 'honda', 'kia', 'kia,'],
#  ['volkswagen'],
#  ['audi'],
#  ['audi'],
#  ['audi', 'honda', 'dodge', 'ford'],
#  ['hyundai'],
#  ['honda'],
#  ['mazda'],
#  ['audi'],
#  ['bmw'],
#  ['mazda'],
#  ['lincoln', 'buick', 'cadillac'],
#  ['bmw'],
#  ['mazda', 'audi'],
#  ['mazda', 'toyota'],
#  ['mazda'],
#  ['audi'],
#  ['audi'],
#  ['volkswagen', 'audi'],
#  ['volkswagen', 'audi', 'bmw'],
#  ['pontiac', 'honda'],
#  ['audi'],
#  ['hyundai'],
#  ['hyundai'],
#  ['hyundai'],
#  ['hyundai', 'acura', 'infiniti'],
#  ['volkswagen', 'audi'],
#  ['audi'],
#  ['mercedes'],
#  ['hyundai'],
#  ['bmw'],
#  ['hyundai'],
#  ['bmw'],
#  ['hyundai'],
#  ['subaru', 'audi', 'volkswagen'],
#  ['hyundai', 'volkswagen', 'audi', 'ford'],
#  ['mercedes', 'audi', 'bmw'],
#  ['hyundai', 'toyota', 'audi', 'mazda'],
#  ['mazda', 'audi'],
#  ['mazda'],
#  ['toyota'],
#  ['bmw', 'honda'],
#  ['toyota', 'honda'],
#  ['acura', 'bmw', 'honda'],
#  ['mazda', 'audi', 'volkswagen'],
#  ['mazda', 'audi', 'volkswagen'],
#  ['honda'],
#  ['audi'],
#  ['ford'],
#  ['audi'],
#  ['audi'],
#  ['bmw'],
#  ['audi'],
#  ['toyota'],
#  ['bmw'],
#  ['bmw'],
#  ['infiniti'],
#  ['audi'],
#  ['audi'],
#  ['hyundai', 'bmw'],
#  ['hyundai', 'bmw'],
#  ['volkswagen'],
#  ['toyota'],
#  ['audi'],
#  ['audi'],
#  ['volkswagen', 'audi'],
#  ['volkswagen'],
#  ['cadillac'],
#  ['mercedes-benz', 'bmw', 'mercedes'],
#  ['mercedes-benz', 'volvo', 'mercedes'],
#  ['cadillac'],
#  ['ford'],
#  ['ford'],
#  ['toyota', 'bmw'],
#  ['toyota'],
#  ['toyota'],
#  ['volkswagen'],
#  ['bmw'],
#  ['volkswagen'],
#  ['ford'],
#  ['dodge'],
#  ['volkswagen'],
#  ['toyota', 'ford'],
#  ['dodge'],
#  ['hyundai'],
#  ['dodge'],
#  ['volkswagen', 'ford'],
#  ['ford'],
#  ['mercedes-benz', 'bmw', 'mercedes'],
#  ['bmw'],
#  ['bmw'],
#  ['hyundai', 'cadillac'],
#  ['bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['toyota', 'audi'],
#  ['bmw'],
#  ['acura'],
#  ['bmw', 'honda'],
#  ['toyota', 'honda'],
#  ['mazda'],
#  ['bmw'],
#  ['bmw'],
#  ['volkswagen', 'audi'],
#  ['ford'],
#  ['audi'],
#  ['bmw'],
#  ['volkswagen', 'audi'],
#  ['audi'],
#  ['volkswagen'],
#  ['volkswagen', 'audi'],
#  ['toyota', 'audi', 'volkswagen'],
#  ['chevrolet'],
#  ['lincoln'],
#  ['mazda', 'cadillac'],
#  ['bmw'],
#  ['toyota'],
#  ['audi'],
#  ['toyota', 'volkswagen'],
#  ['volkswagen', 'honda', 'cadillac', 'ford'],
#  ['mazda', 'toyota', 'honda', 'volkswagen'],
#  ['volkswagen'],
#  ['volkswagen'],
#  ['volkswagen'],
#  ['bmw'],
#  ['honda'],
#  ['volkswagen'],
#  ['volkswagen', 'audi'],
#  ['volkswagen'],
#  ['volkswagen'],
#  ['volkswagen'],
#  ['mazda', 'toyota', 'bmw', 'chevrolet'],
#  ['volkswagen'],
#  ['volkswagen'],
#  ['volkswagen'],
#  ['volkswagen'],
#  ['volkswagen'],
#  ['hyundai', 'toyota'],
#  ['volkswagen'],
#  ['volkswagen'],
#  ['audi'],
#  ['pontiac', 'bmw'],
#  ['audi'],
#  ['audi'],
#  ['subaru'],
#  ['audi'],
#  ['audi'],
#  ['toyota', 'audi'],
#  ['audi', 'honda', 'chevrolet'],
#  ['mazda', 'volkswagen'],
#  ['volkswagen', 'volvo'],
#  ['buick'],
#  ['audi'],
#  ['toyota', 'bmw'],
#  ['hyundai', 'kia'],
#  ['audi'],
#  ['honda'],
#  ['toyota'],
#  ['hyundai', 'dodge'],
#  ['audi'],
#  ['audi', 'bmw'],
#  ['hyundai', 'bmw'],
#  ['bmw'],
#  ['hyundai'],
#  ['toyota', 'audi', 'bmw'],
#  ['hyundai'],
#  ['bmw'],
#  ['bmw'],
#  ['mercedes', 'audi', 'bmw'],
#  ['chevrolet'],
#  ['volkswagen', 'audi'],
#  ['toyota'],
#  ['chrysler',
#   'pontiac',
#   'toyota',
#   'ford',
#   'cadillac',
#   'chevrolet',
#   'buick',
#   'subaru',
#   'honda'],
#  ['bmw', 'cadillac'],
#  ['bmw'],
#  ['toyota'],
#  ['ford', 'mazda', 'volvo', 'chevrolet', 'subaru'],
#  ['bmw'],
#  ['mercedes', 'toyota'],
#  ['audi'],
#  ['audi'],
#  ['mercedes', 'buick'],
#  ['bmw'],
#  ['honda'],
#  ['mercedes-benz', 'bmw', 'volvo', 'mercedes'],
#  ['toyota', 'cadillac'],
#  ['toyota'],
#  ['bmw'],
#  ['toyota'],
#  ['volvo'],
#  ['acura', 'bmw', 'volvo', 'mercedes-benz', 'mercedes'],
#  ['cadillac'],
#  ['cadillac'],
#  ['cadillac'],
#  ['cadillac'],
#  ['buick', 'chevrolet'],
#  ['acura', 'cadillac'],
#  ['subaru', 'audi'],
#  ['acura', 'honda'],
#  ['subaru', 'honda'],
#  ['toyota', 'bmw', 'ford'],
#  ['honda'],
#  ['subaru', 'audi'],
#  ['subaru', 'ford'],
#  ['toyota', 'audi'],
#  ['audi', 'bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['buick'],
#  ['bmw'],
#  ['toyota', 'bmw'],
#  ['chevrolet'],
#  ['bmw', 'dodge'],
#  ['mercedes', 'audi', 'bmw'],
#  ['subaru'],
#  ['audi', 'bmw'],
#  ['subaru'],
#  ['subaru'],
#  ['subaru', 'audi', 'toyota'],
#  ['volkswagen', 'audi'],
#  ['volkswagen', 'audi'],
#  ['subaru', 'audi'],
#  ['nissan'],
#  ['audi'],
#  ['acura', 'ford', 'audi', 'lincoln', 'volkswagen', 'honda'],
#  ['volkswagen'],
#  ['cadillac'],
#  ['cadillac'],
#  ['cadillac'],
#  ['bmw'],
#  ['audi', 'bmw', 'cadillac'],
#  ['hyundai', 'bmw'],
#  ['mercedes', 'audi', 'bmw'],
#  ['bmw', 'honda'],
#  ['bmw', 'honda'],
#  ['infiniti'],
#  ['acura', 'infiniti'],
#  ['toyota'],
#  ['hyundai', 'subaru'],
#  ['cadillac', 'chevrolet'],
#  ['buick', 'chevrolet'],
#  ['hyundai', 'acura', 'chevrolet'],
#  ['volkswagen', 'audi'],
#  ['volkswagen', 'audi', 'cadillac'],
#  ['mitsubishi', 'cadillac'],
#  ['toyota', 'cadillac'],
#  ['cadillac'],
#  ['mercedes-benz', 'bmw', 'mercedes'],
#  ['mercedes-benz', 'bmw', 'mercedes'],
#  ['cadillac'],
#  ['cadillac'],
#  ['hyundai'],
#  ['audi'],
#  ['audi'],
#  ['mercedes-benz', 'audi', 'bmw', 'mercedes'],
#  ['bmw'],
#  ['bmw'],
#  ['mercedes'],
#  ['audi', 'infiniti'],
#  ['lincoln'],
#  ['mazda'],
#  ['cadillac'],
#  ['cadillac'],
#  ['toyota', 'audi', 'cadillac'],
#  ['mercedes-benz', 'mercedes'],
#  ['mercedes-benz', 'bmw', 'mercedes'],
#  ['mercedes-benz', 'mercedes'],
#  ['mercedes-benz', 'bmw', 'mercedes'],
#  ['mercedes-benz', 'bmw', 'mercedes'],
#  ['mazda'],
#  ['audi'],
#  ['toyota', 'bmw'],
#  ['chevrolet'],
#  ['chevrolet'],
#  ['audi'],
#  ['bmw', 'ford', 'audi', 'mercedes-benz', 'mercedes'],
#  ['cadillac'],
#  ['bmw', 'ford', 'audi', 'mercedes-benz', 'mercedes'],
#  ['cadillac'],
#  ['pontiac', 'ford', 'mercury', 'buick', 'toyota'],
#  ['toyota'],
#  ['ford'],
#  ['bmw', 'cadillac'],
#  ['buick', 'acura', 'audi'],
#  ['hyundai', 'cadillac'],
#  ['cadillac', 'chevrolet'],
#  ['audi'],
#  ['audi', 'honda'],
#  ['infiniti'],
#  ['mazda'],
#  ['audi'],
#  ['bmw'],
#  ['acura', 'bmw', 'cadillac'],
#  ['bmw'],
#  ['toyota'],
#  ['bmw', 'cadillac'],
#  ['toyota'],
#  ['audi', 'bmw', 'cadillac'],
#  ['lincoln'],
#  ['toyota', 'cadillac'],
#  ['audi'],
#  ['bmw', 'ford'],
#  ['acura'],
#  ['acura', 'audi', 'cadillac', 'honda', 'infiniti'],
#  ['audi', 'honda'],
#  ['cadillac'],
#  ['audi'],
#  ['bmw'],
#  ['audi'],
#  ['acura'],
#  ['bmw'],
#  ['ford'],
#  ['bmw', 'honda'],
#  ['hyundai'],
#  ['ford'],
#  ['ford'],
#  ['chevrolet'],
#  ['toyota', 'bmw'],
#  ['nissan', 'bmw', 'honda'],
#  ['bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['volkswagen'],
#  ['volkswagen'],
#  ['volkswagen'],
#  ['acura'],
#  ['bmw'],
#  ['toyota', 'honda'],
#  ['chrysler'],
#  ['bmw'],
#  ['volkswagen'],
#  ['acura'],
#  ['hyundai', 'toyota', 'audi'],
#  ['volkswagen'],
#  ['audi'],
#  ['honda'],
#  ['bmw'],
#  ['kia.', 'kia'],
#  ['chevrolet'],
#  ['toyota', 'volvo', 'volkswagen'],
#  ['bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['audi', 'infiniti'],
#  ['bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['mercedes-benz', 'honda', 'mercedes'],
#  ['dodge'],
#  ['mazda'],
#  ['audi'],
#  ['audi'],
#  ['bmw'],
#  ['acura', 'audi', 'bmw'],
#  ['nissan', 'bmw', 'honda'],
#  ['audi'],
#  ['mazda', 'bmw'],
#  ['mazda', 'bmw'],
#  ['audi'],
#  ['acura', 'honda'],
#  ['mazda', 'bmw'],
#  ['bmw', 'ford', 'mazda', 'volkswagen', 'honda'],
#  ['toyota', 'audi'],
#  ['bmw'],
#  ['bmw'],
#  ['mazda', 'bmw'],
#  ['dodge'],
#  ['honda'],
#  ['acura'],
#  ['audi'],
#  ['honda'],
#  ['bmw'],
#  ['ford', 'mazda', 'audi', 'mercedes-benz', 'mercedes', 'volkswagen'],
#  ['subaru'],
#  ['mazda'],
#  ['audi'],
#  ['hyundai', 'mazda', 'audi', 'volkswagen'],
#  ['toyota', 'dodge'],
#  ['subaru', 'volkswagen'],
#  ['mazda', 'audi'],
#  ['acura', 'mazda', 'chevrolet'],
#  ['volkswagen', 'audi'],
#  ['acura', 'audi', 'bmw', 'cadillac'],
#  ['dodge', 'chevrolet', 'ford'],
#  ['audi'],
#  ['audi'],
#  ['audi', 'honda'],
#  ['volvo'],
#  ['volvo'],
#  ['volvo'],
#  ['audi'],
#  ['audi'],
#  ['volkswagen', 'audi'],
#  ['volkswagen', 'audi', 'bmw'],
#  ['acura'],
#  ['infiniti'],
#  ['honda'],
#  ['volkswagen'],
#  ['dodge', 'volkswagen', 'audi', 'hyundai', 'toyota', 'honda'],
#  ['acura', 'volkswagen'],
#  ['dodge'],
#  ['mazda'],
#  ['chevrolet'],
#  ['dodge'],
#  ['dodge'],
#  ['dodge'],
#  ['hyundai', 'ford'],
#  ['dodge'],
#  ['dodge'],
#  ['subaru', 'audi', 'volkswagen'],
#  ['volkswagen'],
#  ['subaru'],
#  ['hyundai', 'volkswagen'],
#  ['audi'],
#  ['audi', 'bmw'],
#  ['cadillac'],
#  ['audi'],
#  ['chrysler', 'volvo'],
#  ['chevrolet'],
#  ['toyota'],
#  ['hyundai', 'toyota'],
#  ['honda'],
#  ['toyota'],
#  ['toyota', 'honda'],
#  ['audi'],
#  ['bmw'],
#  ['hyundai'],
#  ['acura', 'saturn', 'infiniti'],
#  ['acura'],
#  ['bmw'],
#  ['audi'],
#  ['hyundai', 'toyota'],
#  ['hyundai'],
#  ['toyota'],
#  ['toyota'],
#  ['chrysler', 'toyota', 'volvo'],
#  ['bmw'],
#  ['toyota'],
#  ['hyundai', 'buick', 'toyota'],
#  ['toyota'],
#  ['acura', 'mazda', 'bmw'],
#  ['toyota'],
#  ['toyota'],
#  ['buick', 'chrysler', 'toyota', 'chevrolet'],
#  ['cadillac'],
#  ['audi'],
#  ['mercedes', 'bmw'],
#  ['mercedes', 'bmw'],
#  ['mercedes', 'acura', 'audi'],
#  ['acura', 'bmw', 'audi', 'mercedes', 'honda', 'infiniti'],
#  ['mercedes-benz', 'acura', 'honda', 'mercedes'],
#  ['bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['honda'],
#  ['bmw'],
#  ['audi', 'bmw'],
#  ['bmw'],
#  ['bmw'],
#  ['mercedes'],
#  ['audi'],
#  ['toyota', 'honda'],
#  ['audi'],
#  ['bmw'],
#  ['mazda', 'cadillac'],
#  ['audi'],
#  ['cadillac'],
#  ['audi'],
#  ['chrysler'],
#  ['chrysler', 'kia'],
#  ['bmw', 'chevrolet'],
#  ['toyota'],
#  ['toyota'],
#  ['toyota'],
#  ['toyota'],
#  ['toyota'],
#  ['pontiac', 'infiniti'],
#  ['toyota'],
#  ['toyota', 'bmw'],
#  ['audi'],
#  ['mazda'],
#  ['toyota'],
#  ['volvo'],
#  ['audi'],
#  ['toyota', 'bmw', 'honda'],
#  ['subaru', 'infiniti'],
#  ['subaru', 'infiniti'],
#  ['subaru'],
#  ['subaru', 'infiniti'],
#  ['volvo'],
#  ['cadillac'],
#  ['bmw'],
#  ['mercury', 'bmw'],
#  ['bmw'],
#  ['toyota'],
#  ['honda'],
#  ['audi'],
#  ['audi'],
#  ['volkswagen'],
#  ['honda'],
#  ['acura', 'honda'],
#  ['toyota', 'honda', 'ford'],
#  ['mercedes'],
#  ['toyota', 'honda'],
#  ['ford'],
#  ['acura', 'honda'],
#  ['acura', 'audi', 'honda', 'ford'],
#  ['toyota', 'honda', 'ford'],
#  ['mercedes-benz', 'mercedes'],
#  ['ford'],
#  ['mercedes-benz', 'mercedes'],
#  ['toyota', 'honda', 'ford'],
#  ['volkswagen', 'audi'],
#  ['toyota', 'bmw', 'honda'],
#  ['honda'],
#  ['acura',
#   'bmw',
#   'volkswagen',
#   'ford',
#   'mazda',
#   'mercedes-benz',
#   'mercedes',
#   'toyota',
#   'honda'],
#  ['toyota', 'bmw', 'volkswagen'],
#  ['volkswagen'],
#  ['volkswagen'],
#  ['hyundai'],
#  ['volkswagen'],
#  ['honda'],
#  ['honda'],
#  ['honda'],
#  ['honda'],
#  ['buick', 'honda'],
#  ['volkswagen', 'audi'],
#  ['audi', 'bmw'],
#  ['lincoln', 'audi'],
#  ['lincoln', 'toyota'],
#  ['pontiac', 'bmw'],
#  ['mercedes-benz', 'mercedes'],
#  ['toyota', 'chevrolet'],
#  ['acura'],
#  ...]

# %%
def co_occur(car1, car2):
    freq = 0
    for i in range(len(master_list)):
        if (car1 in master_list[i]) & (car2 in master_list[i]):
            freq += 1
    return freq

def lift(car1, car2):
    return (float(len(text)) * float(co_occur(car1, car2))) / (float(count_series.loc[car1]) * float(count_series.loc[car2]))

# %%
lift('bmw','audi')
# Out:
# 2.012602622530067

# %%
list(count_series[:10].index.values)
# Out:
# ['bmw',
#  'audi',
#  'toyota',
#  'acura',
#  'honda',
#  'volkswagen',
#  'infiniti',
#  'hyundai',
#  'cadillac',
#  'ford']
