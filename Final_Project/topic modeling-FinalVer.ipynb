# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
import pandas as pd
import gensim
from gensim import corpora
from nltk.tokenize import sent_tokenize, word_tokenize
import pyLDAvis.gensim as gensimvis
import pyLDAvis

# %%
Adam_Levine=['Drew_Cole','Jackie_Verna','Mia_Boostrom','Reid_Umstattd']
Alicia_Keys=['Johnny_Bliss','Christiana_Danielle','Kelsea_Johnson','Terrence_Cunningham']
Blake_Shelton=['Austin_Giorgio','Gary_Edwards','Spensha_Baker','Wilkes']
Kelly_Clarkson=['Alexa_Cappelli','D.R._King','Dylan_Hartigan','Tish_Haynes_Keys']
experts={'Alicia_Keys':Alicia_Keys,'Adam_Levine':Adam_Levine,'Blake_Shelton':Blake_Shelton,'Kelly_Clarkson':Kelly_Clarkson}

# %%
for key,value in experts.items():
    for i in range(len(value)):
        print(key,value[i])
        data=pd.read_csv(r'/Users/shanqin/Desktop/TextaAnalysis/Final_Project/data_by_mentor/{}/{}.csv'.format(key,value[i]))
        stop = set(stopwords.words('english'))
        exclude = set(string.punctuation) 
        lemma = WordNetLemmatizer()
        frames = [data['commentText'][pd.notna(data['commentText'])], data['replies.commentText'][pd.notna(data['replies.commentText'])]]
        datanona=pd.concat(frames)
        def clean(doc):
            stop_free = " ".join([i for i in str(doc).lower().split() if i not in stop])
            punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
            other_punc_free=''.join(ch for ch in punc_free if ch!='’')
            normalized = " ".join(lemma.lemmatize(word) for word in other_punc_free.split())
            replacelove=normalized.replace('love','like')
            return replacelove
        datacom=datanona.map(clean)
        datacomtoken=datacom.map(word_tokenize)
        id2word = corpora.Dictionary(datacomtoken)
        corpus=[id2word.doc2bow(text) for text in datacomtoken]

        NUM_TOPICS = 4
        ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=id2word, passes=15)
        topics = ldamodel.print_topics(num_words=12)
        
        vis_data = gensimvis.prepare(ldamodel, corpus, id2word)
        pyLDAvis.save_html(vis_data, value[i]+'.html')
        for topic in topics:
            print(topic)
# Out:
# Alicia_Keys Johnny_Bliss
# /Users/shanqin/anaconda3/lib/python3.6/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# (0, '0.020*"like" + 0.020*"song" + 0.017*"team" + 0.015*"voice" + 0.015*"good" + 0.012*"really" + 0.011*"best" + 0.011*"performance" + 0.010*"better" + 0.010*"home" + 0.008*"johnny" + 0.008*"alicias"')
# (1, '0.044*"song" + 0.037*"like" + 0.016*"one" + 0.016*"adele" + 0.014*"sing" + 0.012*"artist" + 0.010*"season" + 0.008*"it" + 0.008*"way" + 0.008*"karaoke" + 0.008*"ever" + 0.006*"favorite"')
# (2, '0.018*"really" + 0.011*"great" + 0.011*"performance" + 0.011*"go" + 0.011*"good" + 0.011*"like" + 0.010*"song" + 0.008*"he" + 0.008*"3" + 0.008*"far" + 0.008*"job" + 0.008*"kelsea"')
# (3, '0.021*"like" + 0.012*"performance" + 0.012*"amazing" + 0.012*"voice" + 0.012*"top" + 0.012*"a" + 0.011*"great" + 0.009*"get" + 0.009*"time" + 0.009*"l" + 0.009*"ai" + 0.008*"singer"')
# Alicia_Keys Christiana_Danielle
# (0, '0.035*"like" + 0.021*"song" + 0.016*"performance" + 0.011*"good" + 0.011*"best" + 0.009*"girl" + 0.009*"alicia" + 0.007*"queen" + 0.007*"time" + 0.007*"cant" + 0.007*"make" + 0.006*"feel"')
# (1, '0.013*"im" + 0.011*"get" + 0.010*"good" + 0.010*"voice" + 0.009*"one" + 0.009*"shes" + 0.008*"like" + 0.008*"her" + 0.008*"song" + 0.008*"really" + 0.008*"damn" + 0.007*"know"')
# (2, '0.028*"christiana" + 0.013*"alicia" + 0.013*"better" + 0.011*"performance" + 0.010*"win" + 0.010*"jackie" + 0.010*"low" + 0.009*"note" + 0.009*"need" + 0.008*"like" + 0.008*"im" + 0.008*"kelsea"')
# (3, '0.021*"voice" + 0.018*"like" + 0.018*"song" + 0.012*"alicia" + 0.010*"great" + 0.010*"christiana" + 0.010*"omg" + 0.007*"pick" + 0.006*"amazing" + 0.006*"make" + 0.006*"artist" + 0.006*"show"')
# Alicia_Keys Kelsea_Johnson
# (0, '0.084*"kelsea" + 0.026*"like" + 0.020*"lauryn" + 0.019*"hill" + 0.018*"voice" + 0.016*"one" + 0.014*"alicia" + 0.010*"make" + 0.009*"song" + 0.008*"team" + 0.007*"christiana" + 0.007*"girl"')
# (1, '0.035*"voice" + 0.017*"like" + 0.011*"team" + 0.010*"make" + 0.010*"best" + 0.009*"song" + 0.009*"four" + 0.009*"would" + 0.008*"artist" + 0.008*"kelseas" + 0.008*"better" + 0.008*"didnt"')
# (2, '0.035*"like" + 0.016*"song" + 0.013*"hill" + 0.012*"good" + 0.010*"performance" + 0.009*"favorite" + 0.009*"vocal" + 0.007*"ever" + 0.007*"yes" + 0.007*"point" + 0.007*"lauren" + 0.007*"sure"')
# (3, '0.021*"like" + 0.019*"kelsea" + 0.016*"top" + 0.014*"song" + 0.013*"much" + 0.013*"make" + 0.012*"12" + 0.012*"it" + 0.011*"christiana" + 0.011*"team" + 0.010*"alicia" + 0.010*"would"')
# Alicia_Keys Terrence_Cunningham
# (0, '0.010*"one" + 0.010*"voice" + 0.008*"like" + 0.008*"terrence" + 0.007*"something" + 0.006*"much" + 0.006*"he" + 0.006*"piano" + 0.006*"performance" + 0.005*"people" + 0.005*"singer" + 0.004*"need"')
# (1, '0.011*"song" + 0.011*"performance" + 0.010*"like" + 0.009*"piano" + 0.009*"he" + 0.008*"show" + 0.008*"boring" + 0.008*"it" + 0.008*"think" + 0.008*"time" + 0.007*"every" + 0.007*"artist"')
# (2, '0.027*"like" + 0.018*"piano" + 0.012*"he" + 0.009*"time" + 0.008*"terrence" + 0.008*"people" + 0.008*"see" + 0.008*"one" + 0.007*"alicia" + 0.007*"artist" + 0.006*"better" + 0.006*"get"')
# (3, '0.017*"like" + 0.012*"voice" + 0.010*"im" + 0.009*"good" + 0.009*"get" + 0.008*"christiana" + 0.008*"show" + 0.008*"song" + 0.007*"he" + 0.007*"getting" + 0.007*"performance" + 0.007*"terrence"')
# Adam_Levine Drew_Cole
# (0, '0.027*"jackie" + 0.025*"country" + 0.023*"adam" + 0.019*"really" + 0.019*"favorite" + 0.014*"drew" + 0.012*"one" + 0.012*"vote" + 0.011*"team" + 0.010*"voice" + 0.010*"better" + 0.009*"song"')
# (1, '0.013*"drew" + 0.012*"he" + 0.011*"sarah" + 0.011*"song" + 0.010*"gone" + 0.009*"good" + 0.008*"top" + 0.008*"ive" + 0.008*"music" + 0.008*"performance" + 0.008*"like" + 0.008*"better"')
# (2, '0.027*"drew" + 0.016*"voice" + 0.015*"adam" + 0.013*"liked" + 0.012*"country" + 0.011*"wilkes" + 0.011*"show" + 0.010*"season" + 0.010*"two" + 0.008*"like" + 0.008*"thing" + 0.007*"im"')
# (3, '0.023*"song" + 0.010*"drew" + 0.010*"go" + 0.010*"always" + 0.010*"season" + 0.009*"adam" + 0.009*"better" + 0.009*"well" + 0.009*"one" + 0.009*"thank" + 0.009*"voice" + 0.007*"austin"')
# Adam_Levine Jackie_Verna
# (0, '0.016*"song" + 0.015*"performance" + 0.014*"mia" + 0.013*"reid" + 0.012*"even" + 0.011*"drew" + 0.010*"team" + 0.009*"adam" + 0.009*"im" + 0.009*"good" + 0.008*"think" + 0.008*"jackie"')
# (1, '0.016*"adam" + 0.014*"voice" + 0.009*"like" + 0.009*"song" + 0.009*"country" + 0.008*"win" + 0.008*"her" + 0.007*"think" + 0.007*"choice" + 0.007*"well" + 0.007*"sharane" + 0.006*"good"')
# (2, '0.029*"jackie" + 0.028*"like" + 0.014*"mia" + 0.011*"last" + 0.011*"song" + 0.011*"season" + 0.010*"adam" + 0.009*"one" + 0.008*"choice" + 0.008*"night" + 0.008*"performance" + 0.008*"im"')
# (3, '0.030*"jackie" + 0.023*"adam" + 0.018*"reid" + 0.017*"like" + 0.017*"country" + 0.013*"singer" + 0.012*"mia" + 0.010*"drew" + 0.009*"top" + 0.009*"think" + 0.008*"really" + 0.008*"artist"')
# Adam_Levine Mia_Boostrom
# (0, '0.025*"mia" + 0.017*"jackie" + 0.013*"top" + 0.012*"adam" + 0.010*"song" + 0.010*"12" + 0.009*"team" + 0.009*"voice" + 0.008*"foster" + 0.008*"chose" + 0.008*"wouldve" + 0.007*"one"')
# (1, '0.024*"like" + 0.017*"performance" + 0.012*"song" + 0.011*"voice" + 0.011*"people" + 0.011*"mia" + 0.009*"really" + 0.009*"good" + 0.008*"jackie" + 0.008*"karaoke" + 0.008*"night" + 0.007*"sharane"')
# (2, '0.018*"singer" + 0.015*"song" + 0.013*"like" + 0.012*"performance" + 0.010*"im" + 0.009*"best" + 0.008*"brynn" + 0.008*"vocal" + 0.008*"good" + 0.007*"it" + 0.007*"tonight" + 0.007*"her"')
# (3, '0.017*"like" + 0.012*"one" + 0.012*"mia" + 0.010*"sad" + 0.010*"song" + 0.009*"note" + 0.009*"see" + 0.009*"it" + 0.009*"voice" + 0.007*"show" + 0.007*"cant" + 0.007*"go"')
# Adam_Levine Reid_Umstattd
# (0, '0.012*"jackie" + 0.012*"guy" + 0.012*"really" + 0.012*"good" + 0.012*"reid" + 0.012*"deserved" + 0.012*"adam" + 0.010*"actually" + 0.010*"rayshun" + 0.008*"he" + 0.008*"gone" + 0.008*"wilkes"')
# (1, '0.023*"voice" + 0.019*"reid" + 0.017*"adam" + 0.017*"performance" + 0.015*"like" + 0.013*"season" + 0.011*"jackie" + 0.009*"hope" + 0.007*"wrong" + 0.007*"still" + 0.007*"sound" + 0.007*"emily"')
# (2, '0.037*"adam" + 0.019*"season" + 0.017*"reid" + 0.010*"f" + 0.010*"tonight" + 0.009*"great" + 0.009*"one" + 0.008*"watch" + 0.008*"best" + 0.008*"voice" + 0.007*"thinking" + 0.006*"gone"')
# (3, '0.022*"adam" + 0.014*"reid" + 0.012*"top" + 0.012*"vote" + 0.012*"get" + 0.010*"well" + 0.010*"sharane" + 0.010*"britton" + 0.010*"twitter" + 0.010*"im" + 0.008*"jackie" + 0.008*"12"')
# Blake_Shelton Austin_Giorgio
# (0, '0.032*"like" + 0.022*"buble" + 0.018*"sound" + 0.017*"michael" + 0.013*"song" + 0.011*"him" + 0.011*"austin" + 0.009*"im" + 0.009*"go" + 0.008*"blake" + 0.008*"best" + 0.007*"good"')
# (1, '0.041*"song" + 0.017*"choice" + 0.013*"like" + 0.012*"austin" + 0.012*"good" + 0.011*"make" + 0.010*"team" + 0.010*"artist" + 0.009*"voice" + 0.008*"blake" + 0.008*"round" + 0.008*"playoff"')
# (2, '0.039*"like" + 0.024*"song" + 0.016*"austin" + 0.011*"performance" + 0.011*"it" + 0.010*"great" + 0.008*"voice" + 0.008*"think" + 0.008*"look" + 0.008*"really" + 0.008*"competition" + 0.007*"show"')
# (3, '0.043*"song" + 0.014*"justin" + 0.013*"bieber" + 0.011*"turtleneck" + 0.010*"sing" + 0.009*"like" + 0.008*"im" + 0.008*"frank" + 0.008*"sinatra" + 0.008*"performance" + 0.008*"better" + 0.008*"he"')
# Blake_Shelton Gary_Edwards
# (0, '0.036*"country" + 0.016*"like" + 0.016*"world" + 0.015*"america" + 0.010*"right" + 0.010*"people" + 0.009*"song" + 0.009*"one" + 0.007*"get" + 0.007*"life" + 0.007*"understand" + 0.006*"good"')
# (1, '0.071*"song" + 0.017*"choice" + 0.013*"voice" + 0.013*"american" + 0.012*"like" + 0.012*"america" + 0.012*"sing" + 0.011*"message" + 0.011*"get" + 0.009*"perfectly\u200b" + 0.009*"sung" + 0.008*"gary"')
# (2, '0.015*"beautiful" + 0.013*"god" + 0.013*"like" + 0.012*"song" + 0.010*"voice" + 0.010*"singing" + 0.009*"matter" + 0.009*"national" + 0.009*"job" + 0.008*"sing" + 0.008*"america" + 0.008*"better"')
# (3, '0.011*"night" + 0.010*"country" + 0.010*"comment" + 0.009*"vote" + 0.009*"performance" + 0.008*"generic" + 0.008*"hope" + 0.008*"people" + 0.008*"last" + 0.008*"like" + 0.007*"america" + 0.007*"song"')
# Blake_Shelton Spensha_Baker
# (0, '0.017*"voice" + 0.015*"like" + 0.013*"song" + 0.012*"country" + 0.011*"artist" + 0.009*"sound" + 0.009*"feel" + 0.007*"show" + 0.007*"u" + 0.007*"gospel" + 0.007*"genre" + 0.007*"enough"')
# (1, '0.019*"like" + 0.017*"spensha" + 0.015*"song" + 0.013*"it" + 0.013*"voice" + 0.011*"country" + 0.011*"well" + 0.009*"really" + 0.009*"choice" + 0.009*"liked" + 0.007*"carrie" + 0.007*"much"')
# (2, '0.023*"blake" + 0.019*"country" + 0.017*"like" + 0.016*"song" + 0.013*"her" + 0.011*"think" + 0.010*"go" + 0.009*"spensha" + 0.009*"bad" + 0.009*"music" + 0.009*"feel" + 0.009*"hope"')
# (3, '0.028*"like" + 0.028*"song" + 0.021*"voice" + 0.016*"need" + 0.016*"better" + 0.014*"good" + 0.014*"spensha" + 0.011*"right" + 0.011*"country" + 0.011*"choice" + 0.009*"her" + 0.007*"fan"')
# Blake_Shelton Wilkes
# (0, '0.023*"wilkes" + 0.021*"like" + 0.015*"song" + 0.012*"go" + 0.012*"make" + 0.012*"mic" + 0.008*"im" + 0.008*"he" + 0.008*"favorite" + 0.007*"good" + 0.006*"guy" + 0.006*"robbed"')
# (1, '0.025*"wilkes" + 0.015*"blake" + 0.013*"really" + 0.011*"song" + 0.011*"make" + 0.009*"he" + 0.009*"voice" + 0.008*"like" + 0.008*"talented" + 0.007*"him" + 0.007*"think" + 0.007*"pryor"')
# (2, '0.023*"like" + 0.021*"wilkes" + 0.017*"performance" + 0.016*"voice" + 0.011*"song" + 0.010*"he" + 0.008*"get" + 0.008*"best" + 0.008*"gwen" + 0.007*"it" + 0.007*"mic" + 0.007*"good"')
# (3, '0.030*"mic" + 0.018*"save" + 0.015*"wilkes" + 0.014*"like" + 0.013*"amazing" + 0.012*"performance" + 0.011*"drop" + 0.010*"top" + 0.010*"go" + 0.009*"great" + 0.009*"12" + 0.009*"song"')
# Kelly_Clarkson Alexa_Cappelli
# (0, '0.013*"song" + 0.012*"lot" + 0.010*"voice" + 0.010*"people" + 0.010*"show" + 0.010*"performance" + 0.008*"kelly" + 0.008*"liked" + 0.008*"made" + 0.008*"better" + 0.008*"like" + 0.008*"picked"')
# (1, '0.023*"song" + 0.020*"alexa" + 0.018*"like" + 0.013*"kaleb" + 0.011*"season" + 0.011*"dylan" + 0.009*"it" + 0.009*"voice" + 0.008*"girl" + 0.007*"hope" + 0.006*"robbed" + 0.006*"know"')
# (2, '0.039*"song" + 0.023*"choice" + 0.013*"alexa" + 0.013*"kelly" + 0.011*"brynn" + 0.011*"im" + 0.011*"12" + 0.011*"top" + 0.009*"like" + 0.009*"would" + 0.009*"team" + 0.008*"best"')
# (3, '0.040*"robbed" + 0.017*"dr" + 0.014*"good" + 0.013*"like" + 0.013*"kelly" + 0.013*"really" + 0.011*"alexa" + 0.011*"know" + 0.009*"shes" + 0.009*"underrated" + 0.008*"performance" + 0.007*"kaleb"')
# Kelly_Clarkson D.R._King
# (0, '0.033*"song" + 0.027*"like" + 0.016*"choice" + 0.011*"think" + 0.011*"best" + 0.010*"kelly" + 0.010*"sing" + 0.008*"guy" + 0.008*"one" + 0.008*"season" + 0.008*"vocal" + 0.007*"king"')
# (1, '0.014*"good" + 0.014*"really" + 0.013*"king" + 0.011*"kelly" + 0.011*"last" + 0.011*"voice" + 0.011*"nice" + 0.010*"dr" + 0.009*"better" + 0.009*"singer" + 0.008*"east" + 0.008*"anderson"')
# (2, '0.022*"like" + 0.019*"dr" + 0.013*"team" + 0.011*"kelly" + 0.009*"you" + 0.009*"got" + 0.009*"since" + 0.009*"comment" + 0.009*"singer" + 0.007*"know" + 0.007*"performance" + 0.007*"blossom"')
# (3, '0.040*"dr" + 0.020*"like" + 0.013*"happy" + 0.013*"made" + 0.012*"im" + 0.012*"top" + 0.012*"12" + 0.012*"better" + 0.010*"kelly" + 0.010*"kaleb" + 0.008*"king" + 0.008*"season"')
# Kelly_Clarkson Dylan_Hartigan
# (0, '0.019*"song" + 0.016*"dylan" + 0.010*"im" + 0.010*"vote" + 0.010*"format" + 0.009*"it" + 0.009*"better" + 0.008*"make" + 0.008*"choice" + 0.008*"guy" + 0.008*"team" + 0.008*"voice"')
# (1, '0.022*"dylan" + 0.017*"voice" + 0.013*"kelly" + 0.013*"like" + 0.011*"dr" + 0.011*"im" + 0.011*"show" + 0.010*"it" + 0.009*"go" + 0.009*"kaleb" + 0.008*"really" + 0.007*"vote"')
# (2, '0.020*"he" + 0.014*"voice" + 0.013*"like" + 0.011*"one" + 0.011*"really" + 0.011*"good" + 0.010*"top" + 0.009*"make" + 0.008*"kaleb" + 0.008*"performance" + 0.008*"deserved" + 0.007*"dylan"')
# (3, '0.017*"like" + 0.013*"song" + 0.012*"dylan" + 0.011*"tom" + 0.011*"petty" + 0.010*"vote" + 0.009*"im" + 0.008*"great" + 0.008*"pick" + 0.008*"judge" + 0.007*"choice" + 0.007*"go"')
# Kelly_Clarkson Tish_Haynes_Keys
# (0, '0.019*"robbed" + 0.014*"note" + 0.012*"got" + 0.012*"like" + 0.011*"sing" + 0.010*"singer" + 0.009*"best" + 0.008*"im" + 0.008*"country" + 0.007*"song" + 0.007*"kaleb" + 0.007*"make"')
# (1, '0.038*"song" + 0.017*"good" + 0.016*"kyla" + 0.016*"choice" + 0.013*"voice" + 0.013*"it" + 0.012*"much" + 0.011*"better" + 0.010*"great" + 0.008*"one" + 0.008*"season" + 0.008*"bad"')
# (2, '0.014*"kyla" + 0.011*"voice" + 0.011*"season" + 0.010*"like" + 0.010*"team" + 0.010*"country" + 0.010*"gone" + 0.010*"tish" + 0.009*"jackie" + 0.008*"jade" + 0.008*"win" + 0.008*"key"')
# (3, '0.017*"performance" + 0.015*"top" + 0.012*"singer" + 0.012*"jackie" + 0.011*"12" + 0.011*"like" + 0.011*"im" + 0.011*"last" + 0.009*"tish" + 0.009*"kyla" + 0.009*"kaleb" + 0.009*"christiana"')

# %% [markdown]
# ## 3 topics

# %%
for key,value in experts.items():
    for i in range(len(value)):
        print(key,value[i])
        data=pd.read_csv(r'/Users/shanqin/Desktop/TextaAnalysis/Final_Project/data_by_mentor/{}/{}.csv'.format(key,value[i]))
        stop = set(stopwords.words('english'))
        exclude = set(string.punctuation) 
        lemma = WordNetLemmatizer()
        frames = [data['commentText'][pd.notna(data['commentText'])], data['replies.commentText'][pd.notna(data['replies.commentText'])]]
        datanona=pd.concat(frames)
        def clean(doc):
            stop_free = " ".join([i for i in str(doc).lower().split() if i not in stop])
            punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
            other_punc_free=''.join(ch for ch in punc_free if ch!='’')
            normalized = " ".join(lemma.lemmatize(word) for word in other_punc_free.split())
            replacelove=normalized.replace('love','like')
            return replacelove
        datacom=datanona.map(clean)
        datacomtoken=datacom.map(word_tokenize)
        id2word = corpora.Dictionary(datacomtoken)
        corpus=[id2word.doc2bow(text) for text in datacomtoken]

        NUM_TOPICS = 3
        ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=id2word, passes=15)
        topics = ldamodel.print_topics(num_words=12)
        
        for topic in topics:
            print(topic)
# Out:
# Alicia_Keys Johnny_Bliss
# (0, '0.045*"song" + 0.033*"like" + 0.014*"team" + 0.014*"sing" + 0.011*"one" + 0.011*"performance" + 0.010*"adele" + 0.010*"good" + 0.010*"voice" + 0.008*"him" + 0.008*"choice" + 0.007*"artist"')
# (1, '0.017*"like" + 0.015*"really" + 0.012*"get" + 0.011*"idol" + 0.011*"voice" + 0.010*"season" + 0.009*"american" + 0.009*"song" + 0.008*"im" + 0.008*"wish" + 0.007*"better" + 0.006*"johnny"')
# (2, '0.016*"go" + 0.015*"like" + 0.014*"top" + 0.013*"johnny" + 0.012*"really" + 0.012*"great" + 0.011*"better" + 0.011*"think" + 0.010*"good" + 0.009*"performance" + 0.009*"cover" + 0.009*"far"')
# Alicia_Keys Christiana_Danielle
# (0, '0.035*"like" + 0.016*"song" + 0.015*"christiana" + 0.014*"alicia" + 0.010*"voice" + 0.010*"better" + 0.009*"jackie" + 0.009*"best" + 0.009*"terrence" + 0.009*"performance" + 0.008*"her" + 0.008*"im"')
# (1, '0.014*"voice" + 0.011*"christiana" + 0.010*"good" + 0.009*"like" + 0.008*"win" + 0.008*"song" + 0.007*"comment" + 0.006*"show" + 0.006*"yes" + 0.006*"made" + 0.005*"got" + 0.005*"really"')
# (2, '0.013*"performance" + 0.012*"song" + 0.010*"alicia" + 0.010*"key" + 0.009*"one" + 0.009*"go" + 0.009*"know" + 0.008*"christiana" + 0.008*"choice" + 0.008*"girl" + 0.007*"good" + 0.007*"great"')
# Alicia_Keys Kelsea_Johnson
# (0, '0.065*"kelsea" + 0.023*"song" + 0.017*"like" + 0.013*"voice" + 0.009*"good" + 0.007*"need" + 0.007*"sing" + 0.007*"performance" + 0.007*"really" + 0.007*"better" + 0.006*"top" + 0.006*"show"')
# (1, '0.025*"hill" + 0.023*"lauryn" + 0.011*"voice" + 0.011*"song" + 0.010*"alicia" + 0.010*"kelsea" + 0.009*"think" + 0.009*"really" + 0.008*"vibe" + 0.008*"choice" + 0.008*"team" + 0.007*"good"')
# (2, '0.043*"like" + 0.020*"voice" + 0.019*"kelsea" + 0.017*"alicia" + 0.015*"make" + 0.015*"team" + 0.013*"christiana" + 0.011*"one" + 0.010*"top" + 0.009*"best" + 0.009*"would" + 0.008*"12"')
# Alicia_Keys Terrence_Cunningham
# (0, '0.025*"like" + 0.012*"song" + 0.010*"terrence" + 0.009*"voice" + 0.008*"piano" + 0.008*"dislike" + 0.007*"better" + 0.007*"people" + 0.007*"one" + 0.007*"see" + 0.007*"performance" + 0.006*"good"')
# (1, '0.015*"piano" + 0.013*"like" + 0.010*"he" + 0.010*"get" + 0.008*"artist" + 0.008*"alicia" + 0.008*"performance" + 0.008*"im" + 0.008*"show" + 0.008*"christiana" + 0.007*"terrence" + 0.007*"voice"')
# (2, '0.016*"boring" + 0.010*"he" + 0.010*"one" + 0.010*"voice" + 0.009*"getting" + 0.009*"him" + 0.008*"like" + 0.008*"im" + 0.008*"performance" + 0.007*"something" + 0.006*"good" + 0.006*"guy"')
# Adam_Levine Drew_Cole
# (0, '0.019*"adam" + 0.015*"drew" + 0.011*"song" + 0.009*"better" + 0.008*"like" + 0.008*"he" + 0.007*"performance" + 0.007*"voice" + 0.007*"artist" + 0.007*"show" + 0.007*"trying" + 0.007*"last"')
# (1, '0.015*"favorite" + 0.014*"drew" + 0.014*"song" + 0.013*"voice" + 0.013*"music" + 0.011*"jackie" + 0.010*"im" + 0.010*"really" + 0.009*"better" + 0.007*"one" + 0.007*"man" + 0.007*"wrong"')
# (2, '0.021*"drew" + 0.020*"adam" + 0.019*"country" + 0.014*"jackie" + 0.014*"go" + 0.012*"voice" + 0.010*"liked" + 0.009*"vote" + 0.009*"really" + 0.009*"song" + 0.008*"season" + 0.008*"one"')
# Adam_Levine Jackie_Verna
# (0, '0.019*"adam" + 0.018*"country" + 0.018*"like" + 0.014*"jackie" + 0.011*"im" + 0.011*"mia" + 0.009*"artist" + 0.009*"drew" + 0.009*"reid" + 0.008*"yeah" + 0.007*"far" + 0.007*"even"')
# (1, '0.020*"jackie" + 0.014*"adam" + 0.012*"song" + 0.012*"reid" + 0.010*"one" + 0.010*"voice" + 0.010*"performance" + 0.010*"mia" + 0.010*"season" + 0.008*"go" + 0.008*"choice" + 0.008*"really"')
# (2, '0.029*"jackie" + 0.022*"like" + 0.014*"adam" + 0.013*"mia" + 0.012*"think" + 0.012*"better" + 0.012*"song" + 0.010*"her" + 0.009*"choice" + 0.009*"im" + 0.009*"reid" + 0.008*"deserved"')
# Adam_Levine Mia_Boostrom
# (0, '0.018*"mia" + 0.012*"like" + 0.012*"jackie" + 0.011*"singer" + 0.010*"one" + 0.010*"song" + 0.009*"would" + 0.009*"team" + 0.009*"voice" + 0.008*"adam" + 0.008*"sad" + 0.008*"im"')
# (1, '0.010*"like" + 0.009*"performance" + 0.008*"song" + 0.007*"karaoke" + 0.007*"jackie" + 0.007*"12" + 0.007*"people" + 0.007*"used" + 0.005*"cant" + 0.005*"top" + 0.005*"eliminated" + 0.005*"good"')
# (2, '0.021*"like" + 0.017*"song" + 0.017*"mia" + 0.016*"performance" + 0.010*"voice" + 0.009*"it" + 0.008*"vocal" + 0.007*"tonight" + 0.007*"worst" + 0.007*"one" + 0.007*"good" + 0.006*"bad"')
# Adam_Levine Reid_Umstattd
# (0, '0.019*"adam" + 0.013*"twitter" + 0.012*"voice" + 0.012*"vote" + 0.012*"get" + 0.010*"reid" + 0.009*"im" + 0.007*"guy" + 0.007*"well" + 0.007*"show" + 0.007*"britton" + 0.007*"top"')
# (1, '0.022*"adam" + 0.017*"good" + 0.017*"reid" + 0.015*"jackie" + 0.014*"season" + 0.012*"performance" + 0.011*"really" + 0.011*"actually" + 0.011*"rayshun" + 0.010*"he" + 0.009*"voice" + 0.009*"song"')
# (2, '0.025*"adam" + 0.021*"reid" + 0.013*"voice" + 0.012*"like" + 0.008*"f" + 0.008*"sound" + 0.008*"sad" + 0.008*"team" + 0.007*"robbed" + 0.006*"tonight" + 0.006*"hate" + 0.006*"new"')
# Blake_Shelton Austin_Giorgio
# (0, '0.027*"like" + 0.022*"song" + 0.014*"austin" + 0.012*"sound" + 0.010*"him" + 0.009*"man" + 0.008*"yes" + 0.008*"great" + 0.006*"im" + 0.006*"go" + 0.006*"buble" + 0.006*"voice"')
# (1, '0.051*"song" + 0.020*"choice" + 0.016*"good" + 0.014*"performance" + 0.013*"like" + 0.013*"bieber" + 0.011*"sing" + 0.008*"justin" + 0.008*"better" + 0.008*"austin" + 0.007*"think" + 0.007*"blake"')
# (2, '0.033*"like" + 0.019*"michael" + 0.018*"buble" + 0.013*"austin" + 0.009*"song" + 0.009*"round" + 0.007*"sound" + 0.007*"think" + 0.007*"vote" + 0.007*"top" + 0.006*"artist" + 0.006*"one"')
# Blake_Shelton Gary_Edwards
# (0, '0.025*"song" + 0.018*"country" + 0.014*"america" + 0.011*"like" + 0.009*"better" + 0.008*"one" + 0.008*"world" + 0.008*"get" + 0.008*"gary" + 0.008*"right" + 0.007*"cant" + 0.007*"even"')
# (1, '0.031*"song" + 0.017*"country" + 0.017*"like" + 0.013*"america" + 0.011*"voice" + 0.011*"sing" + 0.010*"beautiful" + 0.009*"american" + 0.009*"great" + 0.008*"people" + 0.008*"well" + 0.008*"choice"')
# (2, '0.030*"song" + 0.010*"like" + 0.010*"this" + 0.009*"matter" + 0.008*"good" + 0.007*"sing" + 0.007*"list" + 0.007*"job" + 0.007*"choice" + 0.006*"liked" + 0.006*"say" + 0.006*"get"')
# Blake_Shelton Spensha_Baker
# (0, '0.019*"like" + 0.014*"sound" + 0.012*"voice" + 0.012*"country" + 0.011*"artist" + 0.011*"think" + 0.010*"good" + 0.009*"u" + 0.009*"need" + 0.009*"get" + 0.008*"know" + 0.007*"fan"')
# (1, '0.018*"song" + 0.015*"spensha" + 0.011*"country" + 0.011*"voice" + 0.010*"like" + 0.008*"season" + 0.008*"better" + 0.007*"way" + 0.007*"feel" + 0.007*"blake" + 0.007*"really" + 0.007*"could"')
# (2, '0.029*"song" + 0.028*"like" + 0.017*"country" + 0.017*"voice" + 0.013*"blake" + 0.011*"spensha" + 0.011*"choice" + 0.011*"her" + 0.009*"make" + 0.008*"need" + 0.008*"it" + 0.008*"people"')
# Blake_Shelton Wilkes
# (0, '0.027*"mic" + 0.021*"song" + 0.015*"performance" + 0.014*"like" + 0.012*"voice" + 0.012*"he" + 0.011*"best" + 0.010*"drop" + 0.010*"wilkes" + 0.009*"good" + 0.009*"im" + 0.007*"really"')
# (1, '0.037*"wilkes" + 0.020*"like" + 0.014*"blake" + 0.010*"save" + 0.010*"mic" + 0.009*"top" + 0.009*"amazing" + 0.008*"great" + 0.008*"12" + 0.008*"go" + 0.007*"last" + 0.006*"performance"')
# (2, '0.013*"wilkes" + 0.012*"like" + 0.010*"song" + 0.010*"make" + 0.009*"it" + 0.009*"he" + 0.009*"think" + 0.008*"really" + 0.008*"go" + 0.008*"good" + 0.008*"choice" + 0.008*"cant"')
# Kelly_Clarkson Alexa_Cappelli
# (0, '0.037*"robbed" + 0.018*"alexa" + 0.014*"song" + 0.012*"performance" + 0.008*"dylan" + 0.008*"favorite" + 0.008*"better" + 0.008*"good" + 0.008*"still" + 0.008*"even" + 0.007*"show" + 0.006*"beautiful"')
# (1, '0.025*"song" + 0.021*"like" + 0.016*"kelly" + 0.015*"alexa" + 0.013*"choice" + 0.011*"would" + 0.011*"know" + 0.011*"team" + 0.010*"kaleb" + 0.010*"really" + 0.009*"dr" + 0.009*"im"')
# (2, '0.014*"song" + 0.009*"best" + 0.009*"dylan" + 0.009*"performance" + 0.008*"deserved" + 0.008*"underrated" + 0.008*"shes" + 0.008*"kaleb" + 0.008*"choice" + 0.008*"luck" + 0.007*"lot" + 0.007*"well"')
# Kelly_Clarkson D.R._King
# (0, '0.035*"dr" + 0.021*"like" + 0.017*"kelly" + 0.011*"happy" + 0.011*"performance" + 0.011*"team" + 0.010*"top" + 0.010*"12" + 0.010*"king" + 0.010*"better" + 0.008*"voice" + 0.008*"im"')
# (1, '0.013*"im" + 0.013*"made" + 0.012*"song" + 0.011*"kelly" + 0.009*"really" + 0.009*"glad" + 0.009*"get" + 0.009*"amazing" + 0.009*"like" + 0.008*"got" + 0.008*"still" + 0.007*"choice"')
# (2, '0.024*"like" + 0.018*"dr" + 0.015*"song" + 0.012*"king" + 0.011*"dylan" + 0.009*"sing" + 0.008*"think" + 0.008*"people" + 0.008*"voice" + 0.006*"one" + 0.006*"you" + 0.006*"go"')
# Kelly_Clarkson Dylan_Hartigan
# (0, '0.014*"top" + 0.013*"im" + 0.011*"make" + 0.010*"dylan" + 0.009*"like" + 0.008*"voice" + 0.007*"it" + 0.007*"really" + 0.007*"12" + 0.006*"go" + 0.006*"show" + 0.006*"hand"')
# (1, '0.023*"dylan" + 0.018*"like" + 0.012*"kaleb" + 0.012*"better" + 0.011*"kelly" + 0.010*"dr" + 0.010*"good" + 0.009*"go" + 0.009*"think" + 0.008*"sad" + 0.008*"performance" + 0.008*"singer"')
# (2, '0.019*"voice" + 0.019*"song" + 0.014*"vote" + 0.012*"he" + 0.011*"dylan" + 0.011*"like" + 0.010*"one" + 0.009*"petty" + 0.009*"tom" + 0.009*"choice" + 0.007*"it" + 0.006*"really"')
# Kelly_Clarkson Tish_Haynes_Keys
# (0, '0.024*"song" + 0.017*"kyla" + 0.014*"season" + 0.011*"good" + 0.010*"singer" + 0.010*"think" + 0.010*"better" + 0.009*"choice" + 0.009*"key" + 0.008*"much" + 0.008*"like" + 0.007*"got"')
# (1, '0.020*"top" + 0.017*"jackie" + 0.015*"12" + 0.013*"kaleb" + 0.012*"team" + 0.012*"robbed" + 0.012*"christiana" + 0.009*"kelly" + 0.008*"alicia" + 0.008*"kyla" + 0.008*"best" + 0.007*"performance"')
# (2, '0.015*"like" + 0.014*"voice" + 0.012*"im" + 0.010*"tish" + 0.009*"performance" + 0.008*"kyla" + 0.008*"best" + 0.007*"got" + 0.007*"great" + 0.007*"singer" + 0.007*"it" + 0.007*"america"')
